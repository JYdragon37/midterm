# %%
# 특정 웹사이트에서 실시간 검색어 10가지를 가져오는 코드 작성 (Jupyter Notebook 사용)

import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# Signal.bz 뉴스 페이지에서 실시간 검색어 10가지를 가져오기
URL = "https://signal.bz/news"

# 실시간 검색어 가져오기 함수 (Selenium 사용)
def get_realtime_search_terms(url):
    try:
        # 크롬 드라이버 설정
        chrome_options = Options()
        chrome_options.add_argument("--headless")  # 브라우저 창을 표시하지 않고 실행
        service = Service(ChromeDriverManager().install())
        driver = webdriver.Chrome(service=service, options=chrome_options)
        
        driver.get(url)
        print("웹페이지에 접속했습니다.")
        
        # 실시간 검색어 요소 가져오기
        search_elements = driver.find_elements(By.XPATH, "/html/body/div[1]/div/main/div/section/div/section/section[1]/div[2]/div/div/div/a/span[2]")
        terms = [element.text.strip() for element in search_elements[:10]]
        
        driver.quit()
        return terms
    except Exception as e:
        print(f"실시간 검색어 수집 중 오류 발생: {e}")
        return []

# 검색어 출력 및 저장 함수
def save_search_terms(terms):
    if terms:
        # 데이터프레임으로 변환
        df = pd.DataFrame(terms, columns=['실시간 검색어'])
        # 데이터 저장 (파일명에 현재 날짜 포함)
        current_date = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"realtime_search_terms_{current_date}.csv"
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"검색어가 파일로 저장되었습니다: {filename}")
        # 데이터프레임 출력
        display(df)
    else:
        print("검색어를 가져올 수 없습니다.")

if __name__ == "__main__":
    realtime_terms = get_realtime_search_terms(URL)
    save_search_terms(realtime_terms)
# Out:
# 웹페이지에 접속했습니다.
# 검색어가 파일로 저장되었습니다: realtime_search_terms_20241109_164643.csv
#          실시간 검색어
# 0        금성호 어획량
# 1  홀인원 LPGA 챔피언십
# 2     토트넘 감독 손흥민
# 3   빈지노 미초바 자연분만
# 4    정우성 신현빈 열애설
# 5            전남대
# 6     기차역서 폭탄 터져
# 7      바람의나라 클래식
# 8         교란 항공기
# 9     최강희 연예인 최초

# %%
# 특정 웹사이트에서 실시간 검색어 10가지를 가져오는 코드 작성 (Jupyter Notebook 사용)

import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# Signal.bz 뉴스 페이지에서 실시간 검색어 10가지를 가져오기
URL = "https://signal.bz/news"

# 실시간 검색어 가져오기 함수 (Selenium 사용)
def get_realtime_search_terms(url):
    try:
        # 크롬 드라이버 설정
        chrome_options = Options()
        chrome_options.add_argument("--headless")  # 브라우저 창을 표시하지 않고 실행
        service = Service(ChromeDriverManager().install())
        driver = webdriver.Chrome(service=service, options=chrome_options)
        
        driver.get(url)
        print("웹페이지에 접속했습니다.")
        
        # 실시간 검색어 요소 가져오기
        search_elements = driver.find_elements(By.XPATH, "/html/body/div[1]/div/main/div/section/div/section/section[1]/div[2]/div/div/div/a/span[2]")
        terms = [f"{idx + 1}. {element.text.strip()}" for idx, element in enumerate(search_elements[:10])]
        
        driver.quit()
        return terms
    except Exception as e:
        print(f"실시간 검색어 수집 중 오류 발생: {e}")
        return []

# 검색어 출력 및 저장 함수
def save_search_terms(terms):
    if terms:
        # 데이터프레임으로 변환
        df = pd.DataFrame(terms, columns=['실시간 검색어'])
        # 데이터 저장 (파일명에 현재 날짜 포함)
        current_date = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"실검top10_{current_date}.csv"
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"검색어가 파일로 저장되었습니다: {filename}")
        # 데이터프레임 출력
        display(df)
    else:
        print("검색어를 가져올 수 없습니다.")

if __name__ == "__main__":
    realtime_terms = get_realtime_search_terms(URL)
    save_search_terms(realtime_terms)
# Out:
# 웹페이지에 접속했습니다.
# 검색어가 파일로 저장되었습니다: 실검top10_20241109_165432.csv
#             실시간 검색어
# 0        1. 금성호 어획량
# 1  2. 홀인원 LPGA 챔피언십
# 2     3. 토트넘 감독 손흥민
# 3   4. 빈지노 미초바 자연분만
# 4    5. 정우성 신현빈 열애설
# 5            6. 전남대
# 6     7. 기차역서 폭탄 터져
# 7      8. 바람의나라 클래식
# 8         9. 교란 항공기
# 9    10. 최강희 연예인 최초

# %%
# 특정 웹사이트에서 실시간 검색어 10가지를 가져오는 코드 작성 (Jupyter Notebook 사용)

import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# Signal.bz 뉴스 페이지에서 실시간 검색어 10가지를 가져오기
URL = "https://signal.bz/news"

# 실시간 검색어 가져오기 함수 (Selenium 사용)
def get_realtime_search_terms(url):
    try:
        # 크롬 드라이버 설정
        chrome_options = Options()
        chrome_options.add_argument("--headless")  # 브라우저 창을 표시하지 않고 실행
        service = Service(ChromeDriverManager().install())
        driver = webdriver.Chrome(service=service, options=chrome_options)
        
        driver.get(url)
        print("웹페이지에 접속했습니다.")
        
        # 실시간 검색어 요소 가져오기
        search_elements = driver.find_elements(By.XPATH, "/html/body/div[1]/div/main/div/section/div/section/section[1]/div[2]/div/div/div/a/span[2]")
        terms = [f"{idx + 1}. {element.text.strip()}" for idx, element in enumerate(search_elements[:10])]
        
        driver.quit()
        if terms:
            print("실시간 검색어 수집 성공")
        else:
            print("실시간 검색어를 수집하지 못했습니다.")
        return terms
    except Exception as e:
        print(f"실시간 검색어 수집 중 오류 발생: {e}")
        return []

# 인기 뉴스 가져오기 함수 (Selenium 사용)
def get_popular_news(url):
    try:
        # 크롬 드라이버 설정
        chrome_options = Options()
        chrome_options.add_argument("--headless")  # 브라우저 창을 표시하지 않고 실행
        service = Service(ChromeDriverManager().install())
        driver = webdriver.Chrome(service=service, options=chrome_options)
        
        driver.get(url)
        print("웹페이지에 접속했습니다.")
        
        # 인기 뉴스 요소 가져오기
        popular_news_elements = driver.find_elements(By.XPATH, "/html/body/div[1]/div/main/div/section/div/section/section[3]/div/section/div/div/div/div[2]")
        popular_news = [f"인기 {idx + 1}. {element.text.strip()}" for idx, element in enumerate(popular_news_elements[:10])]
        
        driver.quit()
        if popular_news:
            print("인기 뉴스 수집 성공")
        else:
            print("인기 뉴스를 수집하지 못했습니다.")
        return popular_news
    except Exception as e:
        print(f"인기 뉴스 수집 중 오류 발생: {e}")
        return []

# 검색어 출력 및 저장 함수
def save_search_terms(terms, popular_news):
    if terms:
        # 실시간 검색어 데이터프레임으로 변환
        df = pd.DataFrame(terms, columns=['실시간 검색어'])
        # 데이터 저장 (파일명에 현재 날짜 포함)
        current_date = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"실검top10_{current_date}.csv"
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"검색어가 파일로 저장되었습니다: {filename}")
        # 데이터프레임 출력
        display(df)
    else:
        print("검색어를 가져올 수 없습니다.")
    
    if popular_news:
        # 인기 뉴스 데이터프레임으로 변환
        df_popular = pd.DataFrame(popular_news, columns=['인기 뉴스'])
        # 데이터 저장 (파일명에 현재 날짜 포함)
        filename_popular = f"인기뉴스_{current_date}.csv"
        df_popular.to_csv(filename_popular, index=False, encoding='utf-8-sig')
        print(f"인기 뉴스가 파일로 저장되었습니다: {filename_popular}")
        # 데이터프레임 출력
        display(df_popular)
    else:
        print("인기 뉴스를 가져올 수 없습니다.")

if __name__ == "__main__":
    realtime_terms = get_realtime_search_terms(URL)
    popular_news = get_popular_news(URL)
    save_search_terms(realtime_terms, popular_news)
# Out:
# 웹페이지에 접속했습니다.
# 실시간 검색어 수집 성공
# 웹페이지에 접속했습니다.
# 인기 뉴스 수집 성공
# 검색어가 파일로 저장되었습니다: 실검top10_20241109_170042.csv
#             실시간 검색어
# 0        1. 금성호 어획량
# 1  2. 홀인원 LPGA 챔피언십
# 2     3. 토트넘 감독 손흥민
# 3   4. 빈지노 미초바 자연분만
# 4    5. 정우성 신현빈 열애설
# 5            6. 전남대
# 6     7. 기차역서 폭탄 터져
# 7      8. 바람의나라 클래식
# 8         9. 교란 항공기
# 9    10. 최강희 연예인 최초
# 인기 뉴스가 파일로 저장되었습니다: 인기뉴스_20241109_170042.csv
#                                                인기 뉴스
# 0                 인기 1. 파키스탄 기차역서 폭탄테러 발생…사상자 최소 38명
# 1           인기 2. 기상청 "北 함경북도 길주 북북서쪽서 3.1 지진…자연 지진"
# 2          인기 3. 북한 전파 교란 도발…인천 여객선·어선 GPS 이틀째 한때 장애
# 3  인기 4. "남은 의료진이 좀 더 일하겠습니다"…아주대병원 소아응급실, 토요일 정상...
# 4           인기 5. 평소보다 고등어 너무 많이 잡혀서?…금성호 왜 뒤집혀 침몰했나
# 5              인기 6. 동네 후배 참혹 살해하곤 자수 직전 성매매하러 간 60대
# 6          인기 7. 남양주서 불법좌회전 차량이 오토바이 충돌…20·30대 남녀 사망
# 7         인기 8. 올 3분기 러시아 방문 북한인 3,700여명…2010년 이후 최다
# 8          인기 9. 이틀째 검찰출석 명태균, 돈거래 부인하며 "언론보도 허위" 비판
# 9  인기 10. 커플템에 와인바까지…정우성X신현빈, 13살차 열애설 '초고속 부인' [종합]

# %%
# 특정 웹사이트에서 실시간 검색어 10가지를 가져오는 코드 작성 (Jupyter Notebook 사용)

import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# Signal.bz 뉴스 페이지에서 실시간 검색어 10가지를 가져오기
URL = "https://signal.bz/news"

# 실시간 검색어 가져오기 함수 (Selenium 사용)
def get_realtime_search_terms(url):
    try:
        # 크롬 드라이버 설정
        chrome_options = Options()
        chrome_options.add_argument("--headless")  # 브라우저 창을 표시하지 않고 실행
        service = Service(ChromeDriverManager().install())
        driver = webdriver.Chrome(service=service, options=chrome_options)
        
        driver.get(url)
        print("웹페이지에 접속했습니다.")
        
        # 실시간 검색어 요소 가져오기
        search_elements = driver.find_elements(By.XPATH, "/html/body/div[1]/div/main/div/section/div/section/section[1]/div[2]/div/div/div/a/span[2]")
        terms = [element.text.strip() for element in search_elements[:10]]
        
        driver.quit()
        if terms:
            print("실시간 검색어 수집 성공")
        else:
            print("실시간 검색어를 수집하지 못했습니다.")
        return terms
    except Exception as e:
        print(f"실시간 검색어 수집 중 오류 발생: {e}")
        return []

# 인기 뉴스 가져오기 함수 (Selenium 사용)
def get_popular_news(url):
    try:
        # 크롬 드라이버 설정
        chrome_options = Options()
        chrome_options.add_argument("--headless")  # 브라우저 창을 표시하지 않고 실행
        service = Service(ChromeDriverManager().install())
        driver = webdriver.Chrome(service=service, options=chrome_options)
        
        driver.get(url)
        print("웹페이지에 접속했습니다.")
        
        # 인기 뉴스 요소 가져오기
        popular_news_elements = driver.find_elements(By.XPATH, "/html/body/div[1]/div/main/div/section/div/section/section[3]/div/section/div/div/div/div[2]")
        popular_news = [element.text.strip() for element in popular_news_elements[:10]]
        
        driver.quit()
        if popular_news:
            print("인기 뉴스 수집 성공")
        else:
            print("인기 뉴스를 수집하지 못했습니다.")
        return popular_news
    except Exception as e:
        print(f"인기 뉴스 수집 중 오류 발생: {e}")
        return []

# 검색어 출력 및 저장 함수
def save_search_terms(terms, popular_news):
    if terms:
        # 실시간 검색어 데이터프레임으로 변환
        df = pd.DataFrame(terms, columns=['실시간 검색어'])
        # 데이터 저장 (파일명에 현재 날짜 포함)
        current_date = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"실검top10_{current_date}.csv"
        df.to_csv(filename, index=False, encoding='utf-8-sig')
        print(f"검색어가 파일로 저장되었습니다: {filename}")
        # 데이터프레임 출력
        display(df)
    else:
        print("검색어를 가져올 수 없습니다.")
    
    if popular_news:
        # 인기 뉴스 데이터프레임으로 변환
        df_popular = pd.DataFrame(popular_news, columns=['인기 뉴스'])
        # 데이터 저장 (파일명에 현재 날짜 포함)
        filename_popular = f"인기뉴스_{current_date}.csv"
        df_popular.to_csv(filename_popular, index=False, encoding='utf-8-sig')
        print(f"인기 뉴스가 파일로 저장되었습니다: {filename_popular}")
        # 데이터프레임 출력
        display(df_popular)
    else:
        print("인기 뉴스를 가져올 수 없습니다.")

if __name__ == "__main__":
    realtime_terms = get_realtime_search_terms(URL)
    popular_news = get_popular_news(URL)
    save_search_terms(realtime_terms, popular_news)
# Out:
# 웹페이지에 접속했습니다.
# 실시간 검색어 수집 성공
# 웹페이지에 접속했습니다.
# 인기 뉴스 수집 성공
# 검색어가 파일로 저장되었습니다: 실검top10_20241109_170249.csv
#          실시간 검색어
# 0        금성호 어획량
# 1  홀인원 LPGA 챔피언십
# 2     토트넘 감독 손흥민
# 3   빈지노 미초바 자연분만
# 4    정우성 신현빈 열애설
# 5            전남대
# 6     기차역서 폭탄 터져
# 7      바람의나라 클래식
# 8         교란 항공기
# 9     최강희 연예인 최초
# 인기 뉴스가 파일로 저장되었습니다: 인기뉴스_20241109_170249.csv
#                                             인기 뉴스
# 0                    파키스탄 기차역서 폭탄테러 발생…사상자 최소 38명
# 1              기상청 "北 함경북도 길주 북북서쪽서 3.1 지진…자연 지진"
# 2             북한 전파 교란 도발…인천 여객선·어선 GPS 이틀째 한때 장애
# 3  "남은 의료진이 좀 더 일하겠습니다"…아주대병원 소아응급실, 토요일 정상 진료 재개
# 4              평소보다 고등어 너무 많이 잡혀서?…금성호 왜 뒤집혀 침몰했나
# 5                 동네 후배 참혹 살해하곤 자수 직전 성매매하러 간 60대
# 6             남양주서 불법좌회전 차량이 오토바이 충돌…20·30대 남녀 사망
# 7            올 3분기 러시아 방문 북한인 3,700여명…2010년 이후 최다
# 8             이틀째 검찰출석 명태균, 돈거래 부인하며 "언론보도 허위" 비판
# 9      커플템에 와인바까지…정우성X신현빈, 13살차 열애설 '초고속 부인' [종합]
